# %% [markdown]
# <h1><font color='blue'><center>Minería de datos</center></font></h1>
# <h2><center>Tarea 1</center></h2>
# <h3><center>Dana Reyes</center></h3>

# %% [markdown]
# En esta práctica vamos a escribir un código para hacer una gráfica de la función $y = \sin(x)$.
#
# Si desea información teórica sobre esta función puede consultar en [Wikipedia](https://es.wikipedia.org/wiki/Seno_(trigonometr%C3%ADa)).

# %% [markdown]
# Una imagen que muestra como es la función seno es [imagen0](https://es.wikipedia.org/wiki/Seno_(trigonometr%C3%ADa)#/media/Archivo:Funci%C3%B3n_Trigonom%C3%A9trica_R100.svg).

# %%
import IPython.display as display
display.display(display.Markdown('## Imagén de la gráfica de la función seno'))
# Out:
# ## Imagén de la gráfica de la función seno

# %% [markdown]
# ![imagen0](https://upload.wikimedia.org/wikipedia/commons/thumb/9/96/Funci%C3%B3n_Trigonom%C3%A9trica_R100.svg/1280px-Funci%C3%B3n_Trigonom%C3%A9trica_R100.svg.png)

# %% [markdown]
# Ahora para entender como se grafica la función seno se puede ver el siguiente
# [video](https://www.youtube.com/watch?v=ATcTctC1Ei4).

# %%
from IPython.display import YouTubeVideo as Youtube
Youtube('ATcTctC1Ei4')

# %% [raw]
# !conda install -c anaconda numpy
# !conda install -c anaconda matplotlib

# %%
display.display(display.HTML('<h2>Gráfica de la función seno en python</h2>'))
# Out:
# <h2>Gráfica de la función seno en python</h2>

# %% [markdown]
# Ahora, teniendo un poco de entendimiento de la función seno, con el siguente código se puede graficar la función entre $0$ y $2\pi$.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 30)
y = np.sin(x)

xy = zip(x, y) #zip es el cbind de R

print (x, y, xy)
# Out:
# [0.         0.21666156 0.43332312 0.64998469 0.86664625 1.08330781
#  1.29996937 1.51663094 1.7332925  1.94995406 2.16661562 2.38327719
#  2.59993875 2.81660031 3.03326187 3.24992343 3.466585   3.68324656
#  3.89990812 4.11656968 4.33323125 4.54989281 4.76655437 4.98321593
#  5.1998775  5.41653906 5.63320062 5.84986218 6.06652374 6.28318531] [ 0.00000000e+00  2.14970440e-01  4.19889102e-01  6.05174215e-01
#   7.62162055e-01  8.83512044e-01  9.63549993e-01  9.98533414e-01
#   9.86826523e-01  9.28976720e-01  8.27688998e-01  6.87699459e-01
#   5.15553857e-01  3.19301530e-01  1.08119018e-01 -1.08119018e-01
#  -3.19301530e-01 -5.15553857e-01 -6.87699459e-01 -8.27688998e-01
#  -9.28976720e-01 -9.86826523e-01 -9.98533414e-01 -9.63549993e-01
#  -8.83512044e-01 -7.62162055e-01 -6.05174215e-01 -4.19889102e-01
#  -2.14970440e-01 -2.44929360e-16] <zip object at 0x000002267D306A40>

# %%
plt.figure(figsize=(10,6), dpi=80)

plt.plot(x,y)
plt.grid(axis='both')
plt.xticks([0, np.pi/2, np.pi, 3/2*np.pi, 2*np.pi],
          [r'$0$', r'$\pi/2$', r'$\pi$', r'$3\pi/2$', r'$2\pi$'])
plt.yticks([-1,0,1],
          [r'$-1$', r'$0$', r'$1$'])
plt.show()
